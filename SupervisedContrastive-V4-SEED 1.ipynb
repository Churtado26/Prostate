# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"] = "5"

import torch
torch.set_num_threads(1)
import matplotlib.pyplot as plt
import numpy as np
import random
SEED = 1
from sklearn.model_selection import StratifiedKFold

from Utils import EarlyStopping
from Models import   MertashBiParametricNetworkV3, CB1_BiRe1, CB1_BiRe1_int1, CB1_noSPD, CB1_BiRe1_int2
from Models import CB2_BiRe1, CB2_noSPD, CB2_BiRe1_int1, CB2_BiRe1_int2, CB3_BiRe1, CB3_noSPD, CB3_BiRe1_int1, CB3_BiRe1_int2
from ProstatexDataset import ProstatexDataset
from DatasetManagement import DatasetManagement
from Losses import SupervisedContrastiveLoss, NTXentLoss, TripletLoss
import json
import pandas as pd
import joblib
# device = torch.device('cpu')
# device = torch.device('cuda:0')
device = 'cuda' if torch.cuda.is_available() else 'cpu'

cpu = torch.device('cpu')
#'1.3.4' pandas version
def reset_random_seeds():
    torch.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(SEED)
    random.seed(SEED)
    os.environ['PYTHONHASHSEED'] = str(SEED)

# %%
#/home/Data/Datasets/PROSTATEx/dataframes_processed_training

# %%
import os
os.listdir("/data/PROSTATEx/")
# Out:
# ['dataframes_processed_testing', 'dataframes_processed_training']

# %%
def get_mining_config(args):
    if args['loss_function']['mining']['positives'] is None or args['loss_function']['mining']['negatives'] is None:
        return 'no-mining'
    else:
        rules = {
            'easy': 'e',
            'hard': 'h',
            'semihard': 'sh'
        }
        mining_name ='{}p-{}n'.format(
            rules[args['loss_function']['mining']['positives']],
            rules[args['loss_function']['mining']['negatives']]
        )
        return mining_name

def get_loss_function(args):
    if args['loss_function']['kind'] == 'TripletLoss':
        loss_name = '{}_ts_ephn_m_{}'.format(
            args['loss_function']['kind'],
            args['loss_function']['margin']
        )
    elif args['loss_function']['kind'] == 'n_pair':
        loss_name = args['loss_function']['kind']

    elif args['loss_function']['kind'] == 'NTXentLoss':
        loss_name = '{}_T_{}' .format(
            args['loss_function']['kind'],
            args['loss_function']['temperature']
        )
    
    elif args['loss_function']['kind'] == 'SupervisedContrastiveLoss':
        loss_name = '{}_T_{}' .format(
            args['loss_function']['kind'],
            args['loss_function']['temperature']
        )

    elif args['loss_function']['kind'] == 'max_margin':
        loss_name = '{}_met_{}_mar_{}' .format(
            args['loss_function']['kind'],
            args['loss_function']['metric'],
            args['loss_function']['margin']
        )

    return loss_name

def get_optimizer(args):
    if args['optimizer']['kind'] == 'RMSprop':
        optimizer_name = '{}_mom_{}_lr_{}'.format(
            args['optimizer']['kind'],
            args['optimizer']['momentum'],
            args['optimizer']['learning_rate']
        )
    elif args['optimizer']['kind'] == 'Adam':
        optimizer_name = '{}_lr_{}'.format(
            args['optimizer']['kind'],
            args['optimizer']['learning_rate']
        )
    return optimizer_name

# %%
def fit_contrastive(model, train_data, val_data, args):
    
    train_losses = []
    val_losses = []
    early_stopping = EarlyStopping(patience=args['epochs']*0.05)
    
    if args['loss_function']['kind'] == 'NTXentLoss':
        criterion = NTXentLoss(
            temperature = args['loss_function']['temperature'],
            positives = args['loss_function']['mining']['positives'],
            negatives = args['loss_function']['mining']['negatives']
        )
    elif args['loss_function']['kind'] == 'TripletLoss':
        criterion = TripletLoss(
            margin=args['loss_function']['margin'],
            positives = args['loss_function']['mining']['positives'],
            negatives = args['loss_function']['mining']['negatives']
        )
        
    elif args['loss_function']['kind'] == 'SupervisedContrastiveLoss':
        criterion = SupervisedContrastiveLoss(
            temperature=args['loss_function']['temperature'],
        )
    
    if args['optimizer']['kind'] == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=args['optimizer']['learning_rate'])
    elif args['optimizer']['kind'] == 'RMSprop':
        optimizer = torch.optim.RMSprop(
            model.parameters(), 
            lr=args['optimizer']['learning_rate'],
            momentum = args['optimizer']['momentum']
        )
    train_loader = torch.utils.data.DataLoader(
        dataset = train_data,
        shuffle = False,
        batch_size = args['batch_size'],
        pin_memory=False
    )
    val_loader = torch.utils.data.DataLoader(
        dataset = val_data,
        shuffle = False,
        batch_size = args['batch_size'],
        pin_memory=False
    )
    
    #train_loop
    model.train()
    model.to(device)
    model.type(torch.double)
    for epoch in range (args['epochs']):
        if early_stopping.early_stop:
            break;
        running_loss = 0.0
        for i, data in enumerate(train_loader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            for j in range(len(inputs)):
                inputs[j] = inputs[j].to(device)
            labels = labels.to(device)
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model(inputs)
            outputs = torch.nn.functional.normalize(outputs, p=2.0) ## acá es la normalizada la cual ya está en el espacio de contrastivo?
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()* inputs[0].size(0)
        
        running_loss = running_loss / len(train_data)
        train_losses.append(running_loss) #VOY ACÁAAAAAAAAAAAAA
        with torch.no_grad():
            #validation_loop
            model.eval()
            model.to(device)
            val_loss = 0.0
            for i, data in enumerate(val_loader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                for j in range(len(inputs)):
                    inputs[j] = inputs[j].to(device)
                labels = labels.to(device)
                # forward + backward + optimize
                outputs = model(inputs)
                outputs = torch.nn.functional.normalize(outputs, p=2.0)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs[0].size(0)
            val_loss = val_loss / len(val_data)
            val_losses.append(val_loss)

            early_stopping(val_loss)
            if (epoch+1) % 25 == 0:
                print('Epoch {}, val_loss:{:.3f}, train_loss:{:.3f}'.format(epoch+1, val_loss, running_loss ))
        
        
    return {
        'loss': train_losses,
        'val_loss': val_losses,
    }

# %%
def fit_linear_top(model, train_data):
    from sklearn.linear_model import LogisticRegression
    from sklearn.svm import SVC
    
    logistic_regressor = LogisticRegression(random_state=SEED)
    svm = SVC(kernel='linear', probability=True, random_state= SEED)
    train_loader = torch.utils.data.DataLoader(
        dataset = train_data,
        shuffle = False,
        batch_size = len(train_data),
        pin_memory=False
    )
    with torch.no_grad():
        #train_loop
        model.train()
        model.to(cpu)
        for i, data in enumerate(train_loader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            outputs = model(inputs)
            outputs = torch.nn.functional.normalize(outputs, p=2.0)
            labels = torch.squeeze(labels, dim=1)
            logistic_regressor.fit(outputs.numpy(), labels.numpy())
            svm.fit(outputs.numpy(), labels.numpy())
            print("labels shape", labels.shape)
            
    print('finished linear training')
    return {
        'svm': svm, 
        'logistic_regression': logistic_regressor
    }

# %%
def evaluate(model, classifiers, test_data):
    import joblib
    
    
    
    svm = classifiers['svm']
    logistic_regressor = classifiers['logistic_regression']
    train_loader = torch.utils.data.DataLoader(
        dataset = test_data,
        shuffle = False,
        batch_size = len(test_data),
        pin_memory=False
    )
    with torch.no_grad():
        #train_loop
        model.eval()
        model.to(cpu)
        for i, data in enumerate(train_loader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            outputs = model(inputs)
            outputs = torch.nn.functional.normalize(outputs, p=2.0)
            #labels = torch.squeeze(labels, dim=1)
            print("labels shape", labels.shape)
            print("embeddings shape", outputs.shape)
            lr_probs = logistic_regressor.predict_proba(outputs.numpy())[:,1]
            svm_probs = svm.predict_proba(outputs.numpy())[:,1]
            
            
    print('finished linear training')
    return {
        'svm_probs': svm_probs, 
        'lr_probs': lr_probs
    }

# %%
def get_fold_of_data(kfold_number):

    FOLD_IDEX_PATH = '/home/churtado26/Data/PICAI/PICAI/picai_folds_indexes.json'
    fold_indexes = open(FOLD_IDEX_PATH, 'r')
    indexdes = json.load(fold_indexes)
    #indexdes.keys()

    training_target_kfold = 'Fold_{}_train'.format(kfold_number)
    validation_target_kfold = 'Fold_{}_val'.format(kfold_number)


    # REVISAR EL PSA EN EL JSON!!
    BASE_PATH = '/home/churtado26/Data/PICAI/PICAI/patches/'
    JSON_PATH = os.path.join(BASE_PATH, 'info-12x32x32.json')
    IMAGES_PATH = os.path.join(BASE_PATH, 'size-12x32x32')
    file = open(JSON_PATH, 'r')

    metadata = json.load(file)
    file_names = os.listdir(IMAGES_PATH)


    X_train = []
    Y_train = []
    
    ids_train = []
    ids_val = []

    X_validation = []
    Y_validation = []



    for patient_id in indexdes[training_target_kfold]:
        file_name = '{}.npy'.format(patient_id)
        img = np.load(os.path.join(IMAGES_PATH, file_name))
        X_train.append(img)
        ids_train.append(patient_id)

        y = metadata[patient_id]['label']
        Y_train.append(y)

    for patient_id in indexdes[validation_target_kfold]:
        file_name = '{}.npy'.format(patient_id)
        img = np.load(os.path.join(IMAGES_PATH, file_name))
        X_validation.append(img)
        ids_val.append(patient_id)

        y = metadata[patient_id]['label']
        Y_validation.append(y)
        
    return np.array(X_train), np.array(X_validation), np.array(Y_train), np.array(Y_validation), ids_train, ids_val

# %%
def run_k_fold(args):
    current_fold = 0
    optimizer_name = get_optimizer(args)
    mining_name = get_mining_config(args)   
    base_path = '/home/churtado26/Data/contrastive/Experiments/'
    for fold_number in range(0,5):
            current_fold += 1

            x_train, x_validation ,y_train, y_validation, ids_train, ids_val = get_fold_of_data(fold_number)
            train_dataset = DatasetManagement(x_train, y_train)
            val_dataset = DatasetManagement(x_validation, y_validation)
            test_dataset = val_dataset
            
            
            correct_fold_list = []
            
            for i in range (len(ids_val)):
                correct_fold_list.append('test')
                    

            
            if args['backbone_name'] == 'MertashBiParametricNetworkV3':
                model = MertashBiParametricNetworkV3(device, args['target_shape'], args['sequence_embedding_features'], 'contrastive')
                print('loaded MertashBiParametricNetworkV3 model')
            history = fit_contrastive(model, train_dataset, val_dataset, args)
            plt.plot(history['loss'], label = 'loss')
            plt.plot(history['val_loss'], label = 'val_loss')
            plt.legend()
            plt.show()
            classifiers = fit_linear_top(model, train_dataset)
            probs = evaluate(model, classifiers, test_dataset)
            
            joblib.dump(
                classifiers['svm'],
                base_path+'models/svm_fold_{}.pkl'.format(current_fold)
            )
            joblib.dump(
                classifiers['logistic_regression'],
                base_path+'models/lr_fold_{}.pkl'.format(current_fold)
            )
#             print(len(ids_train)) #1035
#             print(len(ids_val))#260
#             print(len(all_idx))#1295
#             print(len(correct_fold_list))#1295
#             print(len(y_validation))#260
#             print(len(probs['lr_probs'].tolist()))#260
#             print(len(probs['svm_probs'].tolist()))#260
            
            
            kfold_dataframe = pd.DataFrame(
                {
                 'indexes': ids_val,
                 'folds': correct_fold_list,   
                 'labels': y_validation.tolist(),
                 'lr_probs': probs['lr_probs'].tolist(),
                 'svm_probs': probs['svm_probs'].tolist()
                }
            )
            kfold_dataframe.to_csv('{}/results/kfold_results_{}.csv'.format(base_path, current_fold))            
            
            directory = os.path.join(base_path, 'models')
            if not os.path.exists(directory):
                os.makedirs(directory)
            
            torch.save(                
                model.state_dict(), 
                base_path+'models/mertash_contrastive_fold_{}.pt'.format(current_fold)
                )
            
#             kfold_dataframe = pd.DataFrame(
#                 {
#                  'labels': y_validation.tolist(),
#                  'lr_probs': probs['lr_probs'].tolist(),
#                  'svm_probs': probs['svm_probs'].tolist()
#                 }
#             )
#             kfold_dataframe.to_csv('{}/results/kfold_results_{}.csv'.format(base_path, fold_number))

# %%
args = {
                        'subsampling_strategy':{
                            'name': 'subsampling_criteria',
                            'percentage': 'train_data_percentage'
                        },
                        'optimizer':{
                            'kind': 'RMSprop',
                            'learning_rate': 1e-6,
                            'momentum': 0.6
                        },
                        'loss_function': {
                                'kind': 'NTXentLoss',
                                'temperature': 0.07,
                                'mining': {
                                    'positives': 'easy',
                                    'negatives': 'semihard'
                                }
                        },
                        'number_folds': 5,
                        'backbone_name': 'MertashBiParametricNetworkV3',
                        'data': 'mertash',
                        'sequence_embedding_features': 256,
                        'target_shape': (12, 32, 32),
                        'batch_size': 32,
                        'epochs': 5000,
                    }
run_k_fold(args)
# Out:
# loaded MertashBiParametricNetworkV3 model
# Epoch 25, val_loss:0.286, train_loss:0.291
# Epoch 50, val_loss:0.155, train_loss:0.136
# Epoch 75, val_loss:0.143, train_loss:0.117
# Epoch 100, val_loss:0.133, train_loss:0.097
# Epoch 125, val_loss:0.120, train_loss:0.086
# Epoch 150, val_loss:0.118, train_loss:0.085
# Epoch 175, val_loss:0.109, train_loss:0.071
# Epoch 200, val_loss:0.115, train_loss:0.068
# Epoch 225, val_loss:0.103, train_loss:0.060
# Epoch 250, val_loss:0.104, train_loss:0.066
# Epoch 275, val_loss:0.112, train_loss:0.054
# Epoch 300, val_loss:0.114, train_loss:0.055
# Epoch 325, val_loss:0.106, train_loss:0.053
# Epoch 350, val_loss:0.107, train_loss:0.050
# Epoch 375, val_loss:0.091, train_loss:0.048
# Epoch 400, val_loss:0.100, train_loss:0.045
# Epoch 425, val_loss:0.099, train_loss:0.038
# Epoch 450, val_loss:0.090, train_loss:0.038
# Epoch 475, val_loss:0.093, train_loss:0.032
# Epoch 500, val_loss:0.093, train_loss:0.032
# Epoch 525, val_loss:0.090, train_loss:0.033
# Epoch 550, val_loss:0.104, train_loss:0.030
# Epoch 575, val_loss:0.096, train_loss:0.029
# Epoch 600, val_loss:0.104, train_loss:0.029
# Epoch 625, val_loss:0.101, train_loss:0.025
# Epoch 650, val_loss:0.096, train_loss:0.026
# Epoch 675, val_loss:0.104, train_loss:0.026
# Epoch 700, val_loss:0.108, train_loss:0.025
# Epoch 725, val_loss:0.105, train_loss:0.022
# Epoch 750, val_loss:0.098, train_loss:0.023
# Epoch 775, val_loss:0.103, train_loss:0.019
# Epoch 800, val_loss:0.113, train_loss:0.020
# INFO: Early stopping
# labels shape torch.Size([1035])
# finished linear training
# labels shape torch.Size([260, 1])
# embeddings shape torch.Size([260, 128])
# finished linear training
# loaded MertashBiParametricNetworkV3 model
# Epoch 25, val_loss:0.192, train_loss:0.212
# Epoch 50, val_loss:0.123, train_loss:0.109
# Epoch 75, val_loss:0.119, train_loss:0.092
# Epoch 100, val_loss:0.100, train_loss:0.080
# Epoch 125, val_loss:0.082, train_loss:0.068
# Epoch 150, val_loss:0.083, train_loss:0.060
# Epoch 175, val_loss:0.080, train_loss:0.054
# Epoch 200, val_loss:0.081, train_loss:0.051
# Epoch 225, val_loss:0.079, train_loss:0.044
# Epoch 250, val_loss:0.079, train_loss:0.041
# Epoch 275, val_loss:0.080, train_loss:0.038
# Epoch 300, val_loss:0.073, train_loss:0.038
# Epoch 325, val_loss:0.075, train_loss:0.034
# Epoch 350, val_loss:0.075, train_loss:0.033
# Epoch 375, val_loss:0.075, train_loss:0.029
# Epoch 400, val_loss:0.078, train_loss:0.025
# Epoch 425, val_loss:0.072, train_loss:0.021
# Epoch 450, val_loss:0.067, train_loss:0.022
# Epoch 475, val_loss:0.071, train_loss:0.018
# Epoch 500, val_loss:0.075, train_loss:0.019
# Epoch 525, val_loss:0.076, train_loss:0.017
# Epoch 550, val_loss:0.085, train_loss:0.015
# Epoch 575, val_loss:0.081, train_loss:0.015
# Epoch 600, val_loss:0.075, train_loss:0.013
# INFO: Early stopping
# labels shape torch.Size([1031])
# finished linear training
# labels shape torch.Size([264, 1])
# embeddings shape torch.Size([264, 128])
# finished linear training
# loaded MertashBiParametricNetworkV3 model
# Epoch 25, val_loss:0.408, train_loss:0.409
# Epoch 50, val_loss:0.112, train_loss:0.111
# Epoch 75, val_loss:0.112, train_loss:0.089
# Epoch 100, val_loss:0.101, train_loss:0.074
# Epoch 125, val_loss:0.114, train_loss:0.070
# Epoch 150, val_loss:0.112, train_loss:0.067
# Epoch 175, val_loss:0.105, train_loss:0.059
# Epoch 200, val_loss:0.107, train_loss:0.057
# Epoch 225, val_loss:0.101, train_loss:0.052
# Epoch 250, val_loss:0.093, train_loss:0.051
# Epoch 275, val_loss:0.086, train_loss:0.041
# Epoch 300, val_loss:0.085, train_loss:0.046
# Epoch 325, val_loss:0.077, train_loss:0.040
# Epoch 350, val_loss:0.076, train_loss:0.036
# Epoch 375, val_loss:0.065, train_loss:0.033
# Epoch 400, val_loss:0.070, train_loss:0.030
# Epoch 425, val_loss:0.073, train_loss:0.026
# Epoch 450, val_loss:0.069, train_loss:0.028
# Epoch 475, val_loss:0.080, train_loss:0.025
# Epoch 500, val_loss:0.064, train_loss:0.023
# Epoch 525, val_loss:0.062, train_loss:0.020
# Epoch 550, val_loss:0.059, train_loss:0.029
# Epoch 575, val_loss:0.067, train_loss:0.015
# Epoch 600, val_loss:0.068, train_loss:0.017
# Epoch 625, val_loss:0.071, train_loss:0.015
# Epoch 650, val_loss:0.064, train_loss:0.012
# Epoch 675, val_loss:0.070, train_loss:0.012
# Epoch 700, val_loss:0.056, train_loss:0.009
# Epoch 725, val_loss:0.067, train_loss:0.012
# Epoch 750, val_loss:0.071, train_loss:0.013
# Epoch 775, val_loss:0.071, train_loss:0.014
# Epoch 800, val_loss:0.065, train_loss:0.007
# Epoch 825, val_loss:0.085, train_loss:0.008
# Epoch 850, val_loss:0.075, train_loss:0.008
# INFO: Early stopping
# labels shape torch.Size([1041])
# finished linear training
# labels shape torch.Size([254, 1])
# embeddings shape torch.Size([254, 128])
# finished linear training
# loaded MertashBiParametricNetworkV3 model
# Epoch 25, val_loss:0.177, train_loss:0.182
# Epoch 50, val_loss:0.091, train_loss:0.084
# Epoch 75, val_loss:0.080, train_loss:0.065
# Epoch 100, val_loss:0.081, train_loss:0.056
# Epoch 125, val_loss:0.076, train_loss:0.051
# Epoch 150, val_loss:0.072, train_loss:0.043
# Epoch 175, val_loss:0.072, train_loss:0.038
# Epoch 200, val_loss:0.073, train_loss:0.035
# Epoch 225, val_loss:0.073, train_loss:0.029
# Epoch 250, val_loss:0.077, train_loss:0.025
# Epoch 275, val_loss:0.070, train_loss:0.021
# Epoch 300, val_loss:0.074, train_loss:0.019
# Epoch 325, val_loss:0.075, train_loss:0.020
# Epoch 350, val_loss:0.071, train_loss:0.017
# Epoch 375, val_loss:0.073, train_loss:0.022
# Epoch 400, val_loss:0.061, train_loss:0.017
# Epoch 425, val_loss:0.065, train_loss:0.017
# Epoch 450, val_loss:0.059, train_loss:0.014
# Epoch 475, val_loss:0.065, train_loss:0.015
# Epoch 500, val_loss:0.060, train_loss:0.012
# Epoch 525, val_loss:0.058, train_loss:0.015
# Epoch 550, val_loss:0.062, train_loss:0.018
# Epoch 575, val_loss:0.065, train_loss:0.017
# Epoch 600, val_loss:0.058, train_loss:0.011
# Epoch 625, val_loss:0.074, train_loss:0.011
# Epoch 650, val_loss:0.056, train_loss:0.011
# Epoch 675, val_loss:0.053, train_loss:0.013
# Epoch 700, val_loss:0.061, train_loss:0.005
# Epoch 725, val_loss:0.053, train_loss:0.013
# Epoch 750, val_loss:0.056, train_loss:0.005
# Epoch 775, val_loss:0.052, train_loss:0.007
# Epoch 800, val_loss:0.057, train_loss:0.005
# Epoch 825, val_loss:0.062, train_loss:0.003
# Epoch 850, val_loss:0.057, train_loss:0.003
# Epoch 875, val_loss:0.058, train_loss:0.003
# Epoch 900, val_loss:0.056, train_loss:0.003
# Epoch 925, val_loss:0.054, train_loss:0.002
# Epoch 950, val_loss:0.061, train_loss:0.002
# Epoch 975, val_loss:0.056, train_loss:0.002
# Epoch 1000, val_loss:0.057, train_loss:0.001
# INFO: Early stopping
# labels shape torch.Size([1030])
# finished linear training
# labels shape torch.Size([265, 1])
# embeddings shape torch.Size([265, 128])
# finished linear training
# loaded MertashBiParametricNetworkV3 model
# Epoch 25, val_loss:0.561, train_loss:0.578
# Epoch 50, val_loss:0.195, train_loss:0.207
# Epoch 75, val_loss:0.154, train_loss:0.145
# Epoch 100, val_loss:0.124, train_loss:0.124
# Epoch 125, val_loss:0.114, train_loss:0.111
# Epoch 150, val_loss:0.105, train_loss:0.108
# Epoch 175, val_loss:0.107, train_loss:0.093
# Epoch 200, val_loss:0.092, train_loss:0.083
# Epoch 225, val_loss:0.089, train_loss:0.082
# Epoch 250, val_loss:0.096, train_loss:0.077
# Epoch 275, val_loss:0.087, train_loss:0.070
# Epoch 300, val_loss:0.082, train_loss:0.068
# Epoch 325, val_loss:0.095, train_loss:0.071
# Epoch 350, val_loss:0.080, train_loss:0.064
# Epoch 375, val_loss:0.089, train_loss:0.060
# Epoch 400, val_loss:0.087, train_loss:0.059
# Epoch 425, val_loss:0.087, train_loss:0.055
# Epoch 450, val_loss:0.085, train_loss:0.052
# Epoch 475, val_loss:0.084, train_loss:0.051
# Epoch 500, val_loss:0.079, train_loss:0.045
# Epoch 525, val_loss:0.079, train_loss:0.043
# Epoch 550, val_loss:0.071, train_loss:0.043
# Epoch 575, val_loss:0.078, train_loss:0.043
# Epoch 600, val_loss:0.084, train_loss:0.044
# Epoch 625, val_loss:0.076, train_loss:0.040
# Epoch 650, val_loss:0.076, train_loss:0.037
# Epoch 675, val_loss:0.065, train_loss:0.036
# Epoch 700, val_loss:0.073, train_loss:0.038
# Epoch 725, val_loss:0.073, train_loss:0.041
# Epoch 750, val_loss:0.073, train_loss:0.039
# Epoch 775, val_loss:0.076, train_loss:0.036
# Epoch 800, val_loss:0.075, train_loss:0.031
# Epoch 825, val_loss:0.072, train_loss:0.031
# Epoch 850, val_loss:0.080, train_loss:0.027
# Epoch 875, val_loss:0.077, train_loss:0.026
# Epoch 900, val_loss:0.086, train_loss:0.025
# Epoch 925, val_loss:0.082, train_loss:0.025
# Epoch 950, val_loss:0.076, train_loss:0.025
# Epoch 975, val_loss:0.070, train_loss:0.029
# INFO: Early stopping
# labels shape torch.Size([1043])
# finished linear training
# labels shape torch.Size([252, 1])
# embeddings shape torch.Size([252, 128])
# finished linear training

# %%
# for subsampling_criteria in ['stratified', 'reduce_negatives', 'reduce_positives', ]:
#     for percentage in [20, 40, 60, 80, 100]:
#         train_data_percentage = percentage / 100
#         args = {
#                                 'subsampling_strategy':{
#                                     'name': subsampling_criteria,
#                                     'percentage': train_data_percentage
#                                 },
#                                 'optimizer':{
#                                     'kind': 'RMSprop',
#                                     'learning_rate': 1e-6,
#                                     'momentum': 0.6
#                                 },
#                                 'loss_function': {
#                                         'kind': 'NTXentLoss',
#                                         'temperature': 0.07,
#                                         'mining': {
#                                             'positives': None,
#                                             'negatives': None
#                                         }
#                                 },
#                                 'number_folds': 5,
#                                 'backbone_name': 'MertashMultiParametricNetworkV2',
#                                 'data': 'mertash',
#                                 'sequence_embedding_features': 512,
#                                 'target_shape': (12, 32, 32),
#                                 'batch_size': 32,
#                                 'epochs': 5000,
#                             }
#         run_k_fold(args)

# %% [markdown]
# # VISUALIZANDO EMBEBIDOS

# %%
weights_path = '/home/churtado26/Data/contrastive/Experiments/models/mertash_contrastive_fold_5.pt'
weights = torch.load(weights_path)
model = MertashBiParametricNetworkV3(args['target_shape'], args['sequence_embedding_features'], 'contrastive')
model.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %%
import numpy as np

x_val_all_0 = []
x_val_all_1 = []
y_val_all_0 = []
y_val_all_1 = []

for fold_number in range(5):
    x_train, x_val, y_train, y_val, ids_train, ids_val = get_fold_of_data(fold_number)
    
    # Crea una máscara booleana para cada clase
    mask_0 = (y_val == 0)
    mask_1 = (y_val == 1)
    
    # Usa la máscara para separar los datos de cada clase
    x_val_all_0.append(x_val[mask_0])
    x_val_all_1.append(x_val[mask_1])
    y_val_all_0.append(y_val[mask_0])
    y_val_all_1.append(y_val[mask_1])

# Concatena los datos de todos los folds para cada clase
x_val_all_0 = np.concatenate(x_val_all_0, axis=0)
x_val_all_1 = np.concatenate(x_val_all_1, axis=0)
y_val_all_0 = np.concatenate(y_val_all_0, axis=0)
y_val_all_1 = np.concatenate(y_val_all_1, axis=0)

# Ahora puedes crear tus DatasetManagement con los datos de validación de cada clase
val_data_0 = DatasetManagement(x_val_all_0, y_val_all_0)
val_data_1 = DatasetManagement(x_val_all_1, y_val_all_1)

# %%
    val_loader0 = torch.utils.data.DataLoader(
        dataset = val_data_0,
        shuffle = False,
        batch_size = args['batch_size'],
        pin_memory=False
    )

# %%
with torch.no_grad():
    #validation_loop
    model.eval()
    model.to(device)
    val_loss = 0.0
    for i, data in enumerate(val_loader0, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        for j in range(len(inputs)):
            inputs[j] = inputs[j].to(device)
        labels = labels.to(device)
        # forward + backward + optimize
        outputs_0 = model(inputs)
        outputs_0 = torch.nn.functional.normalize(outputs_0, p=2.0)

# %%
outputs_0.size()
# Out:
# torch.Size([19, 128])

# %%
import umap

reducer = umap.UMAP(n_components=2)
vectores_2d_0 = reducer.fit_transform(outputs_0.detach().cpu().numpy())

# %% [markdown]
# --------------------------------------

# %%
    val_loader1 = torch.utils.data.DataLoader(
        dataset = val_data_1,
        shuffle = False,
        batch_size = args['batch_size'],
        pin_memory=False
    )

# %%
with torch.no_grad():
    #validation_loop
    model.eval()
    model.to(device)
    val_loss = 0.0
    for i, data in enumerate(val_loader1, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        for j in range(len(inputs)):
            inputs[j] = inputs[j].to(device)
        labels = labels.to(device)
        # forward + backward + optimize
        outputs_1 = model(inputs)
        outputs_1 = torch.nn.functional.normalize(outputs_1, p=2.0)

# %%
import umap

reducer = umap.UMAP(n_components=2)
vectores_2d_1 = reducer.fit_transform(outputs_1.detach().cpu().numpy())

# %%
vectores_2d_1.size
# Out:
# 56

# %%
import matplotlib.pyplot as plt

# Asume que 'vectores_2d_0' y 'vectores_2d_1' son tus vectores bidimensionales de cada clase
plt.figure(figsize=(10, 10))
plt.scatter(vectores_2d_0[:, 0], vectores_2d_0[:, 1], c='blue', label='Benignos')
plt.scatter(vectores_2d_1[:, 0], vectores_2d_1[:, 1], c='red', label='Malignos')
plt.title('Visualización UMAP')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
